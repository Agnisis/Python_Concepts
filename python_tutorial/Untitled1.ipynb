# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np

company=['relience','tata','adani']
Revenue=[110,220,40]

xpos=np.arange(len(company))
xpos
plt.bar(xpos,Revenue,label="Revenue")
# Out:
# <BarContainer object of 3 artists>

# %%
plt.xticks(xpos,company)
plt.ylabel('Revenue')
plt.title("company yearlly Revenue")
plt.bar(xpos,Revenue,width=0.7,color="yellow")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
profit=[10,20,30]
plt.xticks(xpos,company)
plt.ylabel('Revenue')
plt.title("indian companies")
plt.bar(xpos-0.2,Revenue,width=0.3,color="green")
plt.bar(xpos+0.2,Revenue,width=0.2,color="yellow")
plt.grid()
plt.show()

# %%
label={ 'apple','oppo' ,'realme','poco', 'mi','vivo', 'samsung','oneplus'}
shares=[100,80,60,50,90,60,50,60]
plt.pie(x=shares,labels=label,radius=1.5,autopct='%.2f%%')
plt.show()
